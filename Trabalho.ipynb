# %% [markdown]
# # Importando a biblioteca pandas, matplotlib e os DataFrames

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

eventos_1 = pd.read_csv('athlete_events.csv', sep=',')

regiao = pd.read_csv('noc_regions.csv', sep=',')

# %% [markdown]
# ## Visualizando as 5 primeiras linhas dos DataFrames

# %%
display(eventos_1)
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 15 columns]

# %%
display(regiao.head(5))
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %% [markdown]
# ## Verificando informações dos DataFrames

# %%
eventos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Team    271116 non-null  object
#  4   NOC     271116 non-null  object
#  5   Games   271116 non-null  object
#  6   Year    271116 non-null  int64
#  7   Season  271116 non-null  object
#  8   City    271116 non-null  object
#  9   Sport   271116 non-null  object
#  10  Event   271116 non-null  object
#  11  Medal   39783 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 24.8+ MB

# %%
regiao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     230 non-null    object
#  1   region  227 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %% [markdown]
# ## Tipo dos dados do DataFrame

# %%
eventos.dtypes
# Out:
# ID         int64
# Name      object
# Sex       object
# Team      object
# NOC       object
# Games     object
# Year       int64
# Season    object
# City      object
# Sport     object
# Event     object
# Medal     object
# dtype: object

# %%
regiao.dtypes
# Out:
# NOC       object
# region    object
# notes     object
# dtype: object

# %% [markdown]
# ## Verificando a quantidade de linha e colunas

# %%
eventos.shape
# Out:
# (271116, 12)

# %%
regiao.shape
# Out:
# (230, 3)

# %% [markdown]
# ##  Eliminando as colunas dos DataFrames que não serão utilizadas
# ### Aqui vamos trabalha com 2 opções:
# ##### Primeiro caso vamos utilizar drop para eliminar as colunas 'Age', 'Height', 'Weight'

# %%
eventos = eventos_1.drop(['Age', 'Height', 'Weight'], axis=1)

# %% [markdown]
# ## Visualizando o resultado

# %%
display(eventos)
# Out:
#             ID                      Name Sex            Team  NOC  \
# 0            1                 A Dijiang   M           China  CHN
# 1            2                  A Lamusi   M           China  CHN
# 2            3       Gunnar Nielsen Aaby   M         Denmark  DEN
# 3            4      Edgar Lindenau Aabye   M  Denmark/Sweden  DEN
# 4            5  Christine Jacoba Aaftink   F     Netherlands  NED
# ...        ...                       ...  ..             ...  ...
# 271111  135569                Andrzej ya   M        Poland-1  POL
# 271112  135570                  Piotr ya   M          Poland  POL
# 271113  135570                  Piotr ya   M          Poland  POL
# 271114  135571        Tomasz Ireneusz ya   M          Poland  POL
# 271115  135571        Tomasz Ireneusz ya   M          Poland  POL
#
#               Games  Year  Season            City          Sport  \
# 0       1992 Summer  1992  Summer       Barcelona     Basketball
# 1       2012 Summer  2012  Summer          London           Judo
# 2       1920 Summer  1920  Summer       Antwerpen       Football
# 3       1900 Summer  1900  Summer           Paris     Tug-Of-War
# 4       1988 Winter  1988  Winter         Calgary  Speed Skating
# ...             ...   ...     ...             ...            ...
# 271111  1976 Winter  1976  Winter       Innsbruck           Luge
# 271112  2014 Winter  2014  Winter           Sochi    Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi    Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano      Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City      Bobsleigh
#
#                                            Event Medal
# 0                    Basketball Men's Basketball   NaN
# 1                   Judo Men's Extra-Lightweight   NaN
# 2                        Football Men's Football   NaN
# 3                    Tug-Of-War Men's Tug-Of-War  Gold
# 4               Speed Skating Women's 500 metres   NaN
# ...                                          ...   ...
# 271111                Luge Mixed (Men)'s Doubles   NaN
# 271112  Ski Jumping Men's Large Hill, Individual   NaN
# 271113        Ski Jumping Men's Large Hill, Team   NaN
# 271114                      Bobsleigh Men's Four   NaN
# 271115                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 12 columns]

# %% [markdown]
# #####  Segundo caso vamos selecionar as colunas que queremos utilizar 'NOC','region'

# %%
regiao = regiao[['NOC','region']]

# %% [markdown]
# ## Visualizando o resultado

# %%
display(regiao)
# Out:
#      NOC       region
# 0    AFG  Afghanistan
# 1    AHO      Curacao
# 2    ALB      Albania
# 3    ALG      Algeria
# 4    AND      Andorra
# ..   ...          ...
# 225  YEM        Yemen
# 226  YMD        Yemen
# 227  YUG       Serbia
# 228  ZAM       Zambia
# 229  ZIM     Zimbabwe
#
# [230 rows x 2 columns]

# %% [markdown]
# ## Realizando merge dos DataFrames

# %%
eventos_2 = eventos_1.merge(regiao, on='NOC')

# %% [markdown]
# ## Visualizando o resultado

# %%
display(eventos_2.head(5))
# Out:
#      ID           Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 0     1      A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1     2       A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
# 2   602  Abudoureheman   M  22.0   182.0    75.0  China  CHN  2000 Summer
# 3  1463      Ai Linuer   M  25.0   160.0    62.0  China  CHN  2004 Summer
# 4  1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN  2016 Summer
#
#    Year  Season            City       Sport  \
# 0  1992  Summer       Barcelona  Basketball
# 1  2012  Summer          London        Judo
# 2  2000  Summer          Sydney      Boxing
# 3  2004  Summer          Athina   Wrestling
# 4  2016  Summer  Rio de Janeiro    Swimming
#
#                                       Event Medal region
# 0               Basketball Men's Basketball   NaN  China
# 1              Judo Men's Extra-Lightweight   NaN  China
# 2                 Boxing Men's Middleweight   NaN  China
# 3  Wrestling Men's Lightweight, Greco-Roman   NaN  China
# 4     Swimming Women's 200 metres Freestyle   NaN  China

# %% [markdown]
# ## Renomeando as colunas

# %%
eventos_2 = eventos.rename(columns={'Name':'Atleta', 'Sex': 'Sexo', 'Team': 'Equipe', 'Games': 'Jogos', 'Year': 'Ano', 'Season': 'Temporada', 'City': 'Cidade', 'Sport': 'Esporte', 'Event': 'Evento', 'Medal': 'Medalha', 'region': 'Região'})

# %%
display(eventos_2.head(5))
# Out:
#    ID                    Atleta Sexo          Equipe  NOC        Jogos   Ano  \
# 0   1                 A Dijiang    M           China  CHN  1992 Summer  1992
# 1   2                  A Lamusi    M           China  CHN  2012 Summer  2012
# 2   3       Gunnar Nielsen Aaby    M         Denmark  DEN  1920 Summer  1920
# 3   4      Edgar Lindenau Aabye    M  Denmark/Sweden  DEN  1900 Summer  1900
# 4   5  Christine Jacoba Aaftink    F     Netherlands  NED  1988 Winter  1988
#
#   Temporada     Cidade        Esporte                            Evento  \
# 0    Summer  Barcelona     Basketball       Basketball Men's Basketball
# 1    Summer     London           Judo      Judo Men's Extra-Lightweight
# 2    Summer  Antwerpen       Football           Football Men's Football
# 3    Summer      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War
# 4    Winter    Calgary  Speed Skating  Speed Skating Women's 500 metres
#
#   Medalha
# 0     NaN
# 1     NaN
# 2     NaN
# 3    Gold
# 4     NaN

# %% [markdown]
# ## Remover as linhas onde medalha for igual a 'NaN'

# %%
eventos_3 = eventos_2.dropna()

# %%
display(eventos_3.head(5))
# Out:
#     ID                    Atleta Sexo          Equipe  NOC        Jogos   Ano  \
# 3    4      Edgar Lindenau Aabye    M  Denmark/Sweden  DEN  1900 Summer  1900
# 37  15      Arvo Ossian Aaltonen    M         Finland  FIN  1920 Summer  1920
# 38  15      Arvo Ossian Aaltonen    M         Finland  FIN  1920 Summer  1920
# 40  16  Juhamatti Tapio Aaltonen    M         Finland  FIN  2014 Winter  2014
# 41  17   Paavo Johannes Aaltonen    M         Finland  FIN  1948 Summer  1948
#
#    Temporada     Cidade     Esporte                                  Evento  \
# 3     Summer      Paris  Tug-Of-War             Tug-Of-War Men's Tug-Of-War
# 37    Summer  Antwerpen    Swimming  Swimming Men's 200 metres Breaststroke
# 38    Summer  Antwerpen    Swimming  Swimming Men's 400 metres Breaststroke
# 40    Winter      Sochi  Ice Hockey             Ice Hockey Men's Ice Hockey
# 41    Summer     London  Gymnastics  Gymnastics Men's Individual All-Around
#
#    Medalha
# 3     Gold
# 37  Bronze
# 38  Bronze
# 40  Bronze
# 41  Bronze

# %% [markdown]
# ## Ordenando pelo ano no formato Ascending = True

# %%
eventos_4 = eventos_3.sort_values(['Ano'])

display(eventos_4.head(10))
# Out:
#             ID                     Atleta Sexo         Equipe  NOC  \
# 23916    12563  Conrad Helmut Fritz Bcker    M        Germany  GER
# 244276  122329            Georgios Tsitas    M         Greece  GRE
# 214352  107613             Carl Schuhmann    M        Germany  GER
# 214351  107613             Carl Schuhmann    M        Germany  GER
# 214348  107613             Carl Schuhmann    M        Germany  GER
# 194678   97712     Leonidas "Leon" Pyrgos    M         Greece  GRE
# 204732  102806              Richard Rstel    M        Germany  GER
# 204734  102806              Richard Rstel    M        Germany  GER
# 214346  107613             Carl Schuhmann    M        Germany  GER
# 42249    21795       Ellery Harding Clark    M  United States  USA
#
#               Jogos   Ano Temporada  Cidade     Esporte  \
# 23916   1896 Summer  1896    Summer  Athina  Gymnastics
# 244276  1896 Summer  1896    Summer  Athina   Wrestling
# 214352  1896 Summer  1896    Summer  Athina  Gymnastics
# 214351  1896 Summer  1896    Summer  Athina   Wrestling
# 214348  1896 Summer  1896    Summer  Athina  Gymnastics
# 194678  1896 Summer  1896    Summer  Athina     Fencing
# 204732  1896 Summer  1896    Summer  Athina  Gymnastics
# 204734  1896 Summer  1896    Summer  Athina  Gymnastics
# 214346  1896 Summer  1896    Summer  Athina  Gymnastics
# 42249   1896 Summer  1896    Summer  Athina   Athletics
#
#                                               Evento Medalha
# 23916         Gymnastics Men's Horizontal Bar, Teams    Gold
# 244276  Wrestling Men's Unlimited Class, Greco-Roman  Silver
# 214352        Gymnastics Men's Horizontal Bar, Teams    Gold
# 214351  Wrestling Men's Unlimited Class, Greco-Roman    Gold
# 214348         Gymnastics Men's Parallel Bars, Teams    Gold
# 194678       Fencing Men's Foil, Masters, Individual    Gold
# 204732         Gymnastics Men's Parallel Bars, Teams    Gold
# 204734        Gymnastics Men's Horizontal Bar, Teams    Gold
# 214346                  Gymnastics Men's Horse Vault    Gold
# 42249                      Athletics Men's High Jump    Gold

# %% [markdown]
# ## Total de medalhistas por sexo

# %%
medalhista_sexo = eventos_4['Sexo'].value_counts()

# %%
display(medalhista_sexo)
# Out:
# M    28530
# F    11253
# Name: Sexo, dtype: int64

# %%
medalhistas = medalhista_sexo.plot.bar(title='Total de atletas Masculinos e Femininos',
                                        xlabel='Sexo',
                                        ylabel='Total',
                                        color='green')

# %% [markdown]
# ## Total de medalhas de ouros por sexo

# %%
medalhas_de_ouro = eventos_4[eventos_4['Medalha'] == 'Gold']

# %%
medalhas_ouro_sexo = medalhas_de_ouro['Sexo'].value_counts()

display(medalhas_ouro_sexo)
# Out:
# M    9625
# F    3747
# Name: Sexo, dtype: int64

# %%
medalhas_ouro_sexo = medalhas_ouro_sexo.plot.bar(title='Total de Medalhas de ouro por sexo',
                                                xlabel='Sexo',
                                                ylabel='Quantidade',
                                                color='gold')

# %% [markdown]
# ## Total de medalhas de prata por sexo

# %%
medalhas_de_prata = eventos_4[eventos_4['Medalha'] == 'Silver']

# %%
medalhas_prata_sexo = medalhas_de_prata['Sexo'].value_counts()

display(medalhas_prata_sexo)
# Out:
# M    9381
# F    3735
# Name: Sexo, dtype: int64

# %%
medalhas_prata_sexo = medalhas_prata_sexo.plot.bar(title='Total de Medalhas de prata por sexo',
                                                xlabel='Sexo',
                                                ylabel='Quantidade',
                                                color='silver')

# %% [markdown]
# ## Total de medalhas de bronze por sexo

# %%
medalhas_de_bronze = eventos_4[eventos_4['Medalha'] == 'Bronze']

# %%
medalhas_bronze_sexo = medalhas_de_bronze['Sexo'].value_counts()

display(medalhas_bronze_sexo)
# Out:
# M    9524
# F    3771
# Name: Sexo, dtype: int64

# %%
medalhas_bronze_sexo = medalhas_bronze_sexo.plot.bar(title='Total de Medalhas de prata por sexo',
                                                xlabel='Sexo',
                                                ylabel='Quantidade',
                                                color='goldenrod')

# %% [markdown]
# ## Total de medalhas conquistadas pelo Brasil

# %%
medalhas_Brasil = eventos_4[eventos_4['NOC'] == 'BRA' ]

# %%
display(medalhas_Brasil.head(5))
# Out:
#             ID                  Atleta Sexo  Equipe  NOC        Jogos   Ano  \
# 224730  112886       Fernando Soledade    M  Brazil  BRA  1920 Summer  1920
# 47792    24637  Afrnio Antnio da Costa    M  Brazil  BRA  1920 Summer  1920
# 47793    24637  Afrnio Antnio da Costa    M  Brazil  BRA  1920 Summer  1920
# 181713   91332      Guilherme Paraense    M  Brazil  BRA  1920 Summer  1920
# 181712   91332      Guilherme Paraense    M  Brazil  BRA  1920 Summer  1920
#
#        Temporada     Cidade   Esporte  \
# 224730    Summer  Antwerpen  Shooting
# 47792     Summer  Antwerpen  Shooting
# 47793     Summer  Antwerpen  Shooting
# 181713    Summer  Antwerpen  Shooting
# 181712    Summer  Antwerpen  Shooting
#
#                                              Evento Medalha
# 224730  Shooting Men's Free Pistol, 50 metres, Team  Bronze
# 47792         Shooting Men's Free Pistol, 50 metres  Silver
# 47793   Shooting Men's Free Pistol, 50 metres, Team  Bronze
# 181713    Shooting Men's Military Pistol, 30 metres    Gold
# 181712  Shooting Men's Free Pistol, 50 metres, Team  Bronze

# %% [markdown]
# ## Total de medalhas de ouro por sexo (Brasil)

# %%
medalhas_O_S_B = medalhas_Brasil[medalhas_Brasil['Medalha'] == 'Gold']

# %%
display(medalhas_O_S_B.head(5))
# Out:
#             ID                         Atleta Sexo  Equipe  NOC        Jogos  \
# 181713   91332             Guilherme Paraense    M  Brazil  BRA  1920 Summer
# 47881    24678      Adhemar Ferreira da Silva    M  Brazil  BRA  1952 Summer
# 47882    24678      Adhemar Ferreira da Silva    M  Brazil  BRA  1956 Summer
# 224203  112616      Marcos Pinto Rizzo Soares    M  Brazil  BRA  1980 Summer
# 185075   93022  Eduardo Henrique Gomes Penido    M  Brazil  BRA  1980 Summer
#
#          Ano Temporada     Cidade    Esporte  \
# 181713  1920    Summer  Antwerpen   Shooting
# 47881   1952    Summer   Helsinki  Athletics
# 47882   1956    Summer  Melbourne  Athletics
# 224203  1980    Summer     Moskva    Sailing
# 185075  1980    Summer     Moskva    Sailing
#
#                                            Evento Medalha
# 181713  Shooting Men's Military Pistol, 30 metres    Gold
# 47881                 Athletics Men's Triple Jump    Gold
# 47882                 Athletics Men's Triple Jump    Gold
# 224203            Sailing Mixed Two Person Dinghy    Gold
# 185075            Sailing Mixed Two Person Dinghy    Gold

# %%
medalhas_O_S_B = medalhas_O_S_B['Sexo'].value_counts()

display(medalhas_O_S_B.head(5))
# Out:
# M    78
# F    31
# Name: Sexo, dtype: int64

# %%
medalhas_O_S_B = medalhas_O_S_B.plot.pie(title='Total de medalhas de Ouro por sexo')

# %% [markdown]
# ## Total de medalhas de prata por sexo (Brasil)

# %%
medalhas_P_S_B = medalhas_Brasil[medalhas_Brasil['Medalha'] == 'Silver']

# %%
display(medalhas_P_S_B.head())
# Out:
#             ID                   Atleta Sexo  Equipe  NOC        Jogos   Ano  \
# 47792    24637   Afrnio Antnio da Costa    M  Brazil  BRA  1920 Summer  1920
# 193788   97270           Nlson Prudncio    M  Brazil  BRA  1968 Summer  1968
# 1651       918      Ademir Roque Kaefer    M  Brazil  BRA  1984 Summer  1984
# 1733       966             Daniel Adler    M  Brazil  BRA  1984 Summer  1984
# 261703  130944  Lus Carlos Coelho Winck    M  Brazil  BRA  1984 Summer  1984
#
#        Temporada       Cidade    Esporte  \
# 47792     Summer    Antwerpen   Shooting
# 193788    Summer  Mexico City  Athletics
# 1651      Summer  Los Angeles   Football
# 1733      Summer  Los Angeles    Sailing
# 261703    Summer  Los Angeles   Football
#
#                                        Evento Medalha
# 47792   Shooting Men's Free Pistol, 50 metres  Silver
# 193788            Athletics Men's Triple Jump  Silver
# 1651                  Football Men's Football  Silver
# 1733      Sailing Mixed Three Person Keelboat  Silver
# 261703                Football Men's Football  Silver

# %%
medalhas_P_S_B = medalhas_P_S_B['Sexo'].value_counts()

display(medalhas_P_S_B.head(5))
# Out:
# M    120
# F     55
# Name: Sexo, dtype: int64

# %%
medalhas_P_S_B = medalhas_P_S_B.plot.pie(title='Total de medalhas de Prata por sexo')

# %% [markdown]
# ## Total de medalhas de bronze por sexo (Brasil)

# %%
medalhas_B_S_B = medalhas_Brasil[medalhas_Brasil['Medalha'] == 'Bronze']

# %%
display(medalhas_B_S_B.head(5))
# Out:
#             ID                  Atleta Sexo  Equipe  NOC        Jogos   Ano  \
# 224730  112886       Fernando Soledade    M  Brazil  BRA  1920 Summer  1920
# 47793    24637  Afrnio Antnio da Costa    M  Brazil  BRA  1920 Summer  1920
# 181712   91332      Guilherme Paraense    M  Brazil  BRA  1920 Summer  1920
# 262475  131327           Sebastio Wolf    M  Brazil  BRA  1920 Summer  1920
# 14409     7767           Dario Barbosa    M  Brazil  BRA  1920 Summer  1920
#
#        Temporada     Cidade   Esporte  \
# 224730    Summer  Antwerpen  Shooting
# 47793     Summer  Antwerpen  Shooting
# 181712    Summer  Antwerpen  Shooting
# 262475    Summer  Antwerpen  Shooting
# 14409     Summer  Antwerpen  Shooting
#
#                                              Evento Medalha
# 224730  Shooting Men's Free Pistol, 50 metres, Team  Bronze
# 47793   Shooting Men's Free Pistol, 50 metres, Team  Bronze
# 181712  Shooting Men's Free Pistol, 50 metres, Team  Bronze
# 262475  Shooting Men's Free Pistol, 50 metres, Team  Bronze
# 14409   Shooting Men's Free Pistol, 50 metres, Team  Bronze

# %%
medalhas_B_S_B = medalhas_B_S_B['Sexo'].value_counts()

display(medalhas_B_S_B.head(5))
# Out:
# M    142
# F     49
# Name: Sexo, dtype: int64

# %%
medalhas_B_S_B = medalhas_B_S_B.plot.pie(title='Total de medalhas de Bronze por sexo')

# %% [markdown]
# ## Total de medalhas por Atletas brasileiros
# ### Vamos trabalha só com as colunas Atleta e Medalha
# #### Aqui vamos utilizar grouby

# %%
colunas = ['Atleta', 'Medalha']

medalhas_atletas = medalhas_Brasil.filter(items=colunas)

medalhas_atletas = medalhas_atletas.groupby('Atleta', as_index=False).count()

medalhas_atletas
# Out:
#                                   Atleta  Medalha
# 0                    Ademir Roque Kaefer        2
# 1    Adenzia Aparecida Ferreira da Silva        1
# 2              Adhemar Ferreira da Silva        2
# 3       Adriana "Adrianinha" Moiss Pinto        1
# 4           Adriana Aparecida dos Santos        2
# ..                                   ...      ...
# 355                der Francis Carbonera        1
# 356              gatha Bednarczuk Rippel        1
# 357        nderson Lus de Abreu Oliveira        1
# 358            rika Cristiano dos Santos        1
# 359    rika Kelly "Kiki" Pereira Coimbra        1
#
# [360 rows x 2 columns]

# %% [markdown]
# ##  Vamos transformar o tipo da coluna medalha de "object" para "int"

# %%
medalhas_atletas['Medalha'] = medalhas_atletas['Medalha'].astype(int)

medalhas_atletas
# Out:
#                                   Atleta  Medalha
# 0                    Ademir Roque Kaefer        2
# 1    Adenzia Aparecida Ferreira da Silva        1
# 2              Adhemar Ferreira da Silva        2
# 3       Adriana "Adrianinha" Moiss Pinto        1
# 4           Adriana Aparecida dos Santos        2
# ..                                   ...      ...
# 355                der Francis Carbonera        1
# 356              gatha Bednarczuk Rippel        1
# 357        nderson Lus de Abreu Oliveira        1
# 358            rika Cristiano dos Santos        1
# 359    rika Kelly "Kiki" Pereira Coimbra        1
#
# [360 rows x 2 columns]

# %%
medalhas_atletas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 360 entries, 0 to 359
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Atleta   360 non-null    object
#  1   Medalha  360 non-null    int32
# dtypes: int32(1), object(1)
# memory usage: 7.0+ KB

# %% [markdown]
# ## Vamos ordenar do maior para o menor

# %%
medalhas_atletas.sort_values('Medalha', ascending=False)
# Out:
#                                      Atleta  Medalha
# 283                          Robert Scheidt        5
# 332                    Torben Schmidt Grael        5
# 141                    Gustavo Frana Borges        4
# 316      Srgio "Escadinha" Dutra dos Santos        4
# 286               Rodrigo "Rodrigo" Santana        3
# ..                                      ...      ...
# 143               Helen Cristina Santos Luz        1
# 142              Hamilton "Careca" de Souza        1
# 138  Grazielle Pinheiro Guimares Nascimento        1
# 137        Givanildo "Hulk" Vieira de Souza        1
# 359       rika Kelly "Kiki" Pereira Coimbra        1
#
# [360 rows x 2 columns]
